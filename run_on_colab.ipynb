# %% [markdown]
# # Parkinson's Disease Progression Prediction - Colab Runner
#
# This notebook sets up the environment and runs the training loop for the Parkinson's project.

# %% [markdown]
# ## 1. Setup Environment
# Mount Google Drive if your data/code is stored there.

# %%
from google.colab import drive
import os
import sys

# Mount Drive
drive.mount('/content/drive')

# Set your project path here (relative to Drive root)
# Example: 'My Drive/Projects/parkinson_project'
PROJECT_PATH = '/content/drive/MyDrive/official_project_parkinson'

if not os.path.exists(PROJECT_PATH):
    print(f"Warning: Path {PROJECT_PATH} does not exist. Please check your Drive structure.")
    # Fallback to current directory if you uploaded files directly to Colab
    PROJECT_PATH = '/content'

print(f"Using Project Path: {PROJECT_PATH}")
os.chdir(PROJECT_PATH)
sys.path.append(PROJECT_PATH)

# %% [markdown]
# ## 2. Verify Data & Setup
# Run the verification script to ensure all files are in place.

# %%
# !python verify_setup.py

# %% [markdown]
# ## 3. Run Training
# Execute the main training loop.

# %%
from train_brain import train
from config import config

# You can override config here if needed
# config.EPOCHS = 10

if __name__ == '__main__':
    train()
